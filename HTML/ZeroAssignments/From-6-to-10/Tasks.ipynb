# %% [markdown]
# # To Get Tasks <a href="https://elzero.org/html-assignments-lesson-from-6-to-10/" target="_blank">Click Here</a>
#
# ***
# ***
# ***
#
# # Task 01 :
#
#  - Which Line Tells The Browser That the Used Language is HTML5 ?
#
#      - First Line Which is ```<!DOCTYPE html>```
#
#  - Which Rendering Mode Does Web Page Follow if You Didn't Specify The Used Version of HTML ?
#
#      - Quirks Mode
#
#
#  - Is That ok if You Used Multiple h1 tags in Page ?
#
#      - No it's a Bad Practice
#
#  - You have an item that has product data and the product title written in h3 does it make sense to put the h2 address inside the same product or not ?
#
#      - No That Doesn't Make Sense, The Headings Structure Should Follow a Logical Hierarchy,
#
#  - What Does h1, h2, h3, h4, h5 and h6 Elements Represent ?
#
#      - They are Heading Tags Used to Structure Web Pages
#
# ***
# ***
# ***

# %% [markdown]
# # Task 02 :
#
#  - Is There any Difference Between The Following Elements When They Appear in Page ?
#
#  ```html
#  <p class="element">Welcome To The New World</p>
#  <p class='element'>Welcome To The New World</p>
#  <p class=element>Welcome To The New World</p>
#  ```
#
#  - There is No Difference Between Them
#
#
# ***
# ***
# ***

# %% [markdown]
# # Task 03 :
#
#  - Is There any Difference Between The Following Elements When They Appear in Page ?
#
#  ```html
#  <p class="element" hidden>Welcome To The New World</p>
#  <p class=element hidden>Welcome To The New World</p>
#  ```
#
#  - There is No Difference Between Them , They Actually Won's Appear in Page Because We Have Used ```hidden``` Attribute Which Make Elements Invisible
#
# ***
# ***
# ***

# %% [markdown]
# # Task 04 :
#
#  - The Following Elements Will Appear With Same Structure They Written in Or Not ?
#
#  ```html
#  <p>Hello World</p>
#
#  <p>
#  Hello World
#  </p>
#
#  <p>
#  Hello
#  World
#  </p>
#
#  <p>
#  Hello
#
#
#  World
#  </p>
#  ```
#
#  - All of Them Will Appear in One Way , Which is :
#      - ```Hello World```
#
# ***
# ***
# ***

# %% [markdown]
# # Task 05 :
#
#  - Determine Which Of The Following Attributes is a Global Attribute ?
#
#      - title (Global)
#
#      - href (Not Global) : Used Only With ```<a>, <link>, <base>``` Elements
#
#      - src (Not Global) Used Only With ```<script>, <iframe>, <img>``` Elements
#
#      - hidden (Global)
#
#      - charset (Not Global) Used Only With ```<meta>``` ELement
#
#      - class (Global)
#
#      - id (Global)
#
#      - type (Not Global) Used Only With ```<script>, <input>, <button>``` Elements
#
# ***
# ***
# ***
